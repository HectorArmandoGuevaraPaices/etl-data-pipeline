# %% [markdown]
# <a href="https://colab.research.google.com/github/HectorArmandoGuevaraPaices/etl-data-pipeline/blob/main/Corredores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url_corredores = "https://raw.githubusercontent.com/HectorArmandoGuevaraPaices/etl-data-pipeline/refs/heads/main/data/raw/corredores.csv"

# %%
corredores = pd.read_csv(url_corredores)

# %%
corredores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_corredor        80 non-null     int64
#  1   nombre             80 non-null     object
#  2   zona               63 non-null     object
#  3   nivel              68 non-null     object
#  4   anios_experiencia  76 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.3+ KB

# %%
def limpiar_dataframe(df):

    df.columns = df.columns.str.strip().str.lower()

    for col in df.select_dtypes(include='object').columns:
        df[col] = df[col].astype(str).str.strip()

    df = df.replace(r'^\s*$', pd.NA, regex=True)

    df = df.drop_duplicates()

    return df

# %%
corredores.to_csv("corredores_curated.csv", index=False)

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Reemplaza con tu URL Externa de Render
# NOTA: Cambia 'postgres://' por 'postgresql://' si es necesario
DB_URL = "postgresql://etl_user:ACBX9YAyr79b3G6jlny5SpHprdNAO7yg@dpg-d6qu5kp5pdvs73bhfmjg-a.oregon-postgres.render.com/etl_seguros_4ivq"

# Creamos el motor de conexión
engine = create_engine(DB_URL)

# %%
query_create = """
CREATE TABLE corredores(
id_corredor INT PRIMARY KEY,
nombre VARCHAR(150),
zona VARCHAR(100),
nivel VARCHAR(50),
anios_experiencia INT
);
"""

try:
    with engine.connect() as connection:
        connection.execute(text(query_create))
        connection.commit()
        print("¡Tabla 'corredores' creada exitosamente en Render!")
except Exception as e:
    print(f"Error al crear la tabla: {e}")
# Out:
# Error al crear la tabla: (psycopg2.errors.DuplicateTable) relation "corredores" already exists
#
# [SQL:
# CREATE TABLE corredores(
# id_corredor INT PRIMARY KEY,
# nombre VARCHAR(150),
# zona VARCHAR(100),
# nivel VARCHAR(50),
# anios_experiencia INT
# );
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
