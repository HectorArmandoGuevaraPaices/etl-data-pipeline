# %% [markdown]
# <a href="https://colab.research.google.com/github/HectorArmandoGuevaraPaices/etl-data-pipeline/blob/main/Aseguradora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url_aseguradoras = "https://raw.githubusercontent.com/HectorArmandoGuevaraPaices/etl-data-pipeline/refs/heads/main/data/raw/aseguradoras.csv"

# %%
aseguradoras = pd.read_csv(url_aseguradoras)

# %%
def limpiar_dataframe(df):

    df.columns = df.columns.str.strip().str.lower()

    for col in df.select_dtypes(include='object').columns:
        df[col] = df[col].astype(str).str.strip()

    df = df.replace(r'^\s*$', pd.NA, regex=True)

    df = df.drop_duplicates()

    return df

# %%
aseguradoras.to_csv("aseguradoras_curated.csv", index=False)
